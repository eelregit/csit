# %% [markdown]
# * [Quick Start — pyGAM documentation](https://pygam.readthedocs.io/en/latest/notebooks/quick_start.html)
# * [A Tour of pyGAM — pyGAM documentation](https://pygam.readthedocs.io/en/latest/notebooks/tour_of_pygam.html#API)
# * pygam has been installed in the base conda environment
# * scikit-sparse cause problem if installed, the problem seems to be from numpy
# * low-mass halos has large discreteness, add noise to all halo masses to suppress this

# %%
from pygam import LinearGAM, s
import numpy as np
from scipy.interpolate import CubicSpline
import matplotlib.pyplot as plt
import bigfile

root_path = '/mnt/sdceph/users/yinli/csit/planck2015/'

sim_types = ['iso', 'mmp', 'ppm']

# %%
boxsize = 1000

lambdaz = 0.03

def s2(lambdaz):
    return 1.5 * lambdaz ** 2

#def s2(lambdaz):
#    return lambdaz*3

seeds = range(1991, 1996)

# %%
def get_halo_masses(boxsize, lambdaz, seeds):
    """Return preprocessed halo masses.
    
    Procedures:
    -----------
    concatenate,
    Sort, before truncate to discard extra low-mass halos
    Truncate, before adding noise to not introduce a bias at low mass end
    Add noise, to suppress the discretness at low mass end
    Sort again, to get catalogs in descending order at the end
    """
    M = {}

    for t in sim_types:

        def nodot(s):
            return str(s).replace('.', '')

        if t != 'iso':
            t_str = f'{t}{nodot(lambdaz)}'
        else:
            t_str = t
        
        halo_files = [f'{root_path}/{boxsize}/{seed}/{t_str}/ASMTH6/halos/'
                      for seed in seeds]

        M[t] = np.empty(0)

        for f in halo_files:
            cat_ = bigfile.BigFile(f)
            M_ = cat_['Mass'][:]
            M[t] = np.concatenate([M[t], M_])

        M[t] = np.sort(M[t])[::-1]

    length = min(len(M[t]) for t in sim_types)
    print(f'Found {length:.2e} matchable halos')

    frac = 0.1  # fraction of minimum halo mass
    noise_std = frac * min(M[t][-1] for t in sim_types)

    for t in sim_types:
        M[t] = M[t][:length]

        M[t] += noise_std * np.random.randn(len(M[t]))

        M[t] = np.sort(M[t])[::-1]
    
    return M


def get_mass_shift(Ma, Mb, lambdaz, n_splines=4, lams=np.logspace(-6, 0, 7)):
    lnMa, lnMb = np.log(Ma), np.log(Mb)
    lnM = 0.5 * (lnMa + lnMb)
    shift = (lnMb - lnMa) / s2(lambdaz)
    
    gam = LinearGAM(s(0, n_splines=n_splines), fit_intercept=False, verbose=True)
    gam = gam.gridsearch(lnM[:, None], shift, lam=lams)
    
    gam.summary()
    print(gam.statistics_)
    print(gam.terms[0].lam)
    
    lnM_ = gam.generate_X_grid(0)
    shift_, shift_w_err = gam.partial_dependence(0, X=lnM_, width=.68)
    
    return np.exp(lnM_).squeeze(), shift_

def plt_mass_shift_scatter(Ma, Mb, lambdaz):
    lnMa, lnMb = np.log(Ma), np.log(Mb)
    lnM = 0.5 * (lnMa + lnMb)
    shift = (lnMb - lnMa) / s2(lambdaz)
    
    plt.scatter(np.exp(lnM), shift, s=0.5, alpha=0.2)


def get_mass_func(M, boxsize, n_splines=4, lams = np.logspace(-6, 0, 7)):
    """Cumulative mass function"""
    lnn = np.log(np.arange(1, 1 + len(M)) * boxsize ** -3)
    lnM = np.log(M)
    
    gam = LinearGAM(s(0, n_splines=n_splines), fit_intercept=False, verbose=True)
    gam = gam.gridsearch(lnM[:, None], lnn, lam=lams)
    
    gam.summary()
    print(gam.statistics_)
    print(gam.terms[0].lam)
    
    lnM_ = gam.generate_X_grid(0)
    lnn_, lnn_w_err = gam.partial_dependence(0, X=lnM_, width=.68)
    
    lnM_ = lnM_.squeeze()
    M_, n_ = np.exp(lnM_), np.exp(lnn_)
    
    # Use spline derivative to get differential mass function
    # - d / dlnM
    dlnn_dlnM = CubicSpline(lnM_, lnn_).derivative(1)
    dlnn_dlnM_ = dlnn_dlnM(lnM_)
    n_p_ = - dlnn_dlnM_ * n_  # n_p_ = n_lnM
    
    dlnnp_dlnM = CubicSpline(lnM_, np.log(n_p_)).derivative(1)
    dlnnp_dlnM_ = dlnnp_dlnM(lnM_)
    n_pp_ = - dlnnp_dlnM_ * n_p_
    
    # mass,
    # cumulative mass function (>M),
    # d n / d ln M = - n_lnM
    # d^2 n / d (ln M)^2
    return M_, n_, n_p_, n_pp_


def plt_mass_func_scatter(M, boxsize):
    """Cumulative mass function"""
    n = np.arange(1, 1 + len(M)) * boxsize ** -3
    
    plt.scatter(M, n, s=0.5, alpha=0.2)

# %%
M = get_halo_masses(boxsize, lambdaz, seeds)
# Out:
# Found 1.44e+07 matchable halos

# %%
M_mmp, shift_mmp = get_mass_shift(M['iso'], M['mmp'], lambdaz, n_splines=4)
M_ppm, shift_ppm = get_mass_shift(M['iso'], M['ppm'], lambdaz, n_splines=4)

plt_mass_shift_scatter(M['iso'], M['mmp'], lambdaz)
plt.plot(M_mmp, shift_mmp, c='k', ls='--')
plt_mass_shift_scatter(M['iso'], M['ppm'], lambdaz)
plt.plot(M_ppm, shift_ppm, c='r', ls='--')

'''
M_ppp, shift_ppp = get_mass_shift(M['iso'], M['ppp'], lambdaz, n_splines=4)
M_mmm, shift_mmm = get_mass_shift(M['mmm'], M['iso'], lambdaz, n_splines=4)

plt_mass_shift_scatter(M['iso'], M['ppp'], lambdaz)
plt_mass_shift_scatter(M['mmm'], M['iso'], lambdaz)
plt.plot(M_ppp, shift_ppp, c='k', ls='--')
plt.plot(M_mmm, shift_mmm, c='b', ls='--')
'''

plt.xscale('log')
# Out:
# N/A% (0 of 7) |                          | Elapsed Time: 0:00:00 ETA:  --:--:--/home/yinli/anaconda/lib/python3.7/site-packages/pygam/utils.py:78: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# 100% (7 of 7) |##########################| Elapsed Time: 0:03:58 Time:  0:03:58
# /home/yinli/anaconda/lib/python3.7/site-packages/ipykernel_launcher.py:60: UserWarning: KNOWN BUG: p-values computed in this summary are likely much smaller than they should be.
#
# Please do not make inferences based on these values!
#
# Collaborate on a solution, and stay up to date at:
# github.com/dswah/pyGAM/issues/163
# LinearGAM
# =============================================== ==========================================================
# Distribution:                        NormalDist Effective DoF:                                      3.9999
# Link Function:                     IdentityLink Log Likelihood:                            -200043807.0629
# Number of Samples:                     14407885 AIC:                                        400087624.1255
#                                                 AICc:                                       400087624.1255
#                                                 GCV:                                                0.0304
#                                                 Scale:                                              0.0304
#                                                 Pseudo R-Squared:                                    0.038
# ==========================================================================================================
# Feature Function                  Lambda               Rank         EDoF         P > x        Sig. Code
# ================================= ==================== ============ ============ ============ ============
# s(0)                              [0.001]              4            4.0          1.11e-16     ***
# ==========================================================================================================
# Significance codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# WARNING: Fitting splines and a linear function to a feature introduces a model identifiability problem
#          which can cause p-values to appear significant when they are not.
#
# WARNING: p-values calculated in this manner behave correctly for un-penalized models or models with
#          known smoothing parameters, but when smoothing parameters have been estimated, the p-values
#          are typically lower than they should be, meaning that the tests reject the null too readily.
# {'n_samples': 14407885, 'm_features': 1, 'edof_per_coef': array([0.99999999, 0.9999998 , 0.99999677, 0.9998925 ]), 'edof': 3.9998890581863864, 'scale': 0.03037770300903712, 'cov': array([[ 1.62924767e-04, -5.16215182e-05,  6.60913359e-05,
#         -4.37253273e-04],
#        [-5.16215182e-05,  1.65381972e-05, -2.13888071e-05,
#          1.44116580e-04],
#        [ 6.60913359e-05, -2.13888071e-05,  2.79511525e-05,
#         -1.92093816e-04],
#        [-4.37253273e-04,  1.44116580e-04, -1.92093816e-04,
#          1.41800999e-03]]), 'se': array([0.0127642 , 0.00406672, 0.00528688, 0.03765647]), 'AIC': 400087624.1254822, 'AICc': 400087624.1254864, 'pseudo_r2': OrderedDict([('explained_deviance', 0.037952398074775684), ('McFadden', 0.955323100985897), ('McFadden_adj', 0.044676879912354917)]), 'GCV': 0.030377718189162392, 'UBRE': None, 'loglikelihood': -200043807.06285205, 'deviance': 14407881.000110954, 'p_values': [1.1102230246251565e-16]}
# [0.001]
# N/A% (0 of 7) |                          | Elapsed Time: 0:00:00 ETA:  --:--:--/home/yinli/anaconda/lib/python3.7/site-packages/pygam/utils.py:78: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# 100% (7 of 7) |##########################| Elapsed Time: 0:03:54 Time:  0:03:54
# /home/yinli/anaconda/lib/python3.7/site-packages/ipykernel_launcher.py:60: UserWarning: KNOWN BUG: p-values computed in this summary are likely much smaller than they should be.
#
# Please do not make inferences based on these values!
#
# Collaborate on a solution, and stay up to date at:
# github.com/dswah/pyGAM/issues/163
# LinearGAM
# =============================================== ==========================================================
# Distribution:                        NormalDist Effective DoF:                                         4.0
# Link Function:                     IdentityLink Log Likelihood:                            -316065752.9676
# Number of Samples:                     14407885 AIC:                                        632131515.9351
#                                                 AICc:                                       632131515.9351
#                                                 GCV:                                                0.0201
#                                                 Scale:                                              0.0201
#                                                 Pseudo R-Squared:                                   0.5075
# ==========================================================================================================
# Feature Function                  Lambda               Rank         EDoF         P > x        Sig. Code
# ================================= ==================== ============ ============ ============ ============
# s(0)                              [0.0001]             4            4.0          1.11e-16     ***
# ==========================================================================================================
# Significance codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# WARNING: Fitting splines and a linear function to a feature introduces a model identifiability problem
#          which can cause p-values to appear significant when they are not.
#
# WARNING: p-values calculated in this manner behave correctly for un-penalized models or models with
#          known smoothing parameters, but when smoothing parameters have been estimated, the p-values
#          are typically lower than they should be, meaning that the tests reject the null too readily.
# {'n_samples': 14407885, 'm_features': 1, 'edof_per_coef': array([1.        , 0.99999998, 0.99999969, 0.99998962]), 'edof': 3.9999892892184437, 'scale': 0.02005843298438739, 'cov': array([[ 9.79764992e-05, -3.14657450e-05,  4.06661776e-05,
#         -2.72923265e-04],
#        [-3.14657450e-05,  1.02190811e-05, -1.33434244e-05,
#          9.12235254e-05],
#        [ 4.06661776e-05, -1.33434244e-05,  1.76105416e-05,
#         -1.22856416e-04],
#        [-2.72923265e-04,  9.12235254e-05, -1.22856416e-04,
#          9.23296146e-04]]), 'se': array([0.00989831, 0.00319673, 0.00419649, 0.03038579]), 'AIC': 632131515.9351022, 'AICc': 632131515.9351064, 'pseudo_r2': OrderedDict([('explained_deviance', 0.5074943189982906), ('McFadden', 0.4606408326943957), ('McFadden_adj', 0.5393591614759363)]), 'GCV': 0.020058443008093115, 'UBRE': None, 'loglikelihood': -316065752.96756184, 'deviance': 14407881.000010714, 'p_values': [1.1102230246251565e-16]}
# [0.0001]

# %%
plt.plot(M_mmp, shift_mmp, c='k', ls='--', label=f'shift from {sim_types[1]}{lambdaz}')
plt.plot(M_ppm, shift_ppm, c='r', ls='--', label=f'shift from {sim_types[2]}{lambdaz}')
plt.xscale('log')
plt.legend()

plt.savefig(f'/home/yinli/csit/analysis/bias/shift_{lambdaz}_comp.pdf')

# %%
plt_mass_shift_scatter(M['iso'], M['mmp'], lambdaz)
plt.plot(M_mmp, shift_mmp, c='k', ls='--')

plt_mass_shift_scatter(M['iso'], M['ppm'], lambdaz)
plt.plot(M_ppm, shift_ppm, c='r', ls='--')
'''
plt_mass_shift_scatter(M['iso'], M['ppp'], lambdaz)
plt.plot(M_ppp, shift_ppp, c='k', ls='--')
plt_mass_shift_scatter(M['mmm'], M['iso'],  lambdaz)
plt.plot(M_mmm, shift_mmm, c='r', ls='--')
'''
#plt.ylim(-0.5, 2)
plt.xscale('log')

# %%
M_, n_, n_p_, n_pp_ = get_mass_func(M['iso'], boxsize, n_splines=4)

plt_mass_func_scatter(M['iso'], boxsize)
plt.plot(M_, n_, label='$n$')
plt.plot(M_, - n_p_, ls='--', label='$n_{\ln M}$')
plt.xscale('log')
plt.yscale('log')
plt.legend()
# Out:
# N/A% (0 of 7) |                          | Elapsed Time: 0:00:00 ETA:  --:--:--/home/yinli/anaconda/lib/python3.7/site-packages/pygam/utils.py:78: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# 100% (7 of 7) |##########################| Elapsed Time: 0:03:54 Time:  0:03:54
# /home/yinli/anaconda/lib/python3.7/site-packages/ipykernel_launcher.py:85: UserWarning: KNOWN BUG: p-values computed in this summary are likely much smaller than they should be.
#
# Please do not make inferences based on these values!
#
# Collaborate on a solution, and stay up to date at:
# github.com/dswah/pyGAM/issues/163
# LinearGAM
# =============================================== ==========================================================
# Distribution:                        NormalDist Effective DoF:                                         4.0
# Link Function:                     IdentityLink Log Likelihood:                          -15888815182.3438
# Number of Samples:                     14407885 AIC:                                      31777630374.6877
#                                                 AICc:                                     31777630374.6877
#                                                 GCV:                                                0.0005
#                                                 Scale:                                              0.0005
#                                                 Pseudo R-Squared:                                   0.9995
# ==========================================================================================================
# Feature Function                  Lambda               Rank         EDoF         P > x        Sig. Code
# ================================= ==================== ============ ============ ============ ============
# s(0)                              [0.]                 4            4.0          1.11e-16     ***
# ==========================================================================================================
# Significance codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# WARNING: Fitting splines and a linear function to a feature introduces a model identifiability problem
#          which can cause p-values to appear significant when they are not.
#
# WARNING: p-values calculated in this manner behave correctly for un-penalized models or models with
#          known smoothing parameters, but when smoothing parameters have been estimated, the p-values
#          are typically lower than they should be, meaning that the tests reject the null too readily.
# {'n_samples': 14407885, 'm_features': 1, 'edof_per_coef': array([1.        , 1.        , 1.        , 0.99999989]), 'edof': 3.9999998912057104, 'scale': 0.00045062406389800603, 'cov': array([[ 2.26210415e-06, -7.23393579e-07,  9.32090140e-07,
#         -6.22552107e-06],
#        [-7.23393579e-07,  2.33928914e-07, -3.04513585e-07,
#          2.07171654e-06],
#        [ 9.32090140e-07, -3.04513585e-07,  4.00627404e-07,
#         -2.78093994e-06],
#        [-6.22552107e-06,  2.07171654e-06, -2.78093994e-06,
#          2.07766184e-05]]), 'se': array([0.00150403, 0.00048366, 0.00063295, 0.00455814]), 'AIC': 31777630374.687702, 'AICc': 31777630374.687706, 'pseudo_r2': OrderedDict([('explained_deviance', 0.9995493713750817), ('McFadden', 0.00044787389748951435), ('McFadden_adj', 0.9995521261023977)]), 'GCV': 0.00045062428908683227, 'UBRE': None, 'loglikelihood': -15888815182.343851, 'deviance': 14407881.00000012, 'p_values': [1.1102230246251565e-16]}
# [1e-06]

# %%
ds_dlnM_mmp = CubicSpline(np.log(M_), shift_mmp).derivative(1)
ds_dlnM_ppm = CubicSpline(np.log(M_), shift_ppm).derivative(1)
shift_ = (shift_mmp + shift_ppm)/2

bLs2 = - (ds_dlnM_mmp(np.log(M_))+ds_dlnM_ppm(np.log(M_)))/2 + shift_* n_pp_/n_p_
bLs2_mmp = -ds_dlnM_mmp(np.log(M_)) + shift_mmp* n_pp_/n_p_
bLs2_ppm = -ds_dlnM_ppm(np.log(M_)) + shift_ppm* n_pp_/n_p_

'''
ds_dlnM_ppp = CubicSpline(np.log(M_ppp), shift_ppp).derivative(1)
ds_dlnM_mmm = CubicSpline(np.log(M_mmm), shift_mmm).derivative(1)
shift_ = (shift_ppp + shift_mmm)/2

bL1 = - (ds_dlnM_ppp(np.log(M_))+ds_dlnM_mmm(np.log(M_)))/2 + shift_* n_pp_/n_p_
bL1_ppp = -ds_dlnM_ppp(np.log(M_)) + shift_ppp* n_pp_/n_p_
bL1_mmm = -ds_dlnM_mmm(np.log(M_)) + shift_mmm* n_pp_/n_p_
'''
# Out:
# '\nds_dlnM_ppp = CubicSpline(np.log(M_ppp), shift_ppp).derivative(1)\nds_dlnM_mmm = CubicSpline(np.log(M_mmm), shift_mmm).derivative(1)\nshift_ = (shift_ppp + shift_mmm)/2\n\nbL1 = - (ds_dlnM_ppp(np.log(M_))+ds_dlnM_mmm(np.log(M_)))/2 + shift_* n_pp_/n_p_\nbL1_ppp = -ds_dlnM_ppp(np.log(M_)) + shift_ppp* n_pp_/n_p_\nbL1_mmm = -ds_dlnM_mmm(np.log(M_)) + shift_mmm* n_pp_/n_p_\n'

# %%
plt.plot(M_, ds_dlnM_mmp(np.log(M_)), ls='-', label=f'$d s/ d ln{M}$ from {sim_types[1]}{lambdaz}')
plt.plot(M_, ds_dlnM_ppm(np.log(M_)), ls='-', label=f'$d s/ d ln{M}$ from {sim_types[2]}{lambdaz}')

'''
plt.plot(M_, ds_dlnM_ppp(np.log(M_)), ls='-', label=r'$\partial s/ \partial \ln{M}$ from ppp')
plt.plot(M_, ds_dlnM_mmm(np.log(M_)), ls='-', label=r'$\partial s/ \partial \ln{M}$ from mmm')
'''

plt.xscale('log')
plt.legend()
plt.savefig(f'/home/yinli/csit/analysis/bias/dsdlnM_{lambdaz}_comp.pdf')

# %%
plt.plot(M_, 2*bLs2, ls='-', label='Eq.(17)')
plt.plot(M_, 2*bLs2_mmp, ls='-', label=f'{sim_types[1]}{lambdaz}')
plt.plot(M_, 2*bLs2_ppm, ls='-', label=f'{sim_types[2]}{lambdaz}')

#plt.plot(massbin, (bLs2_mmp+bLs2_ppm)/2., ls='--', label='Eq.(16)')

plt.xscale('log')
#plt.yscale('log')
#plt.xlim(1e12, 1e15)
#plt.ylim(-3, 6)
plt.legend()
plt.savefig(f'/home/yinli/csit/analysis/bias/bLs2_abmat_{lambdaz}_comp.pdf')

# %%
plt.plot(M_, bL1, ls='-', label='Eq.(17) (ppp+mmm)/2')
plt.plot(M_, bL1_ppp, ls='-', label='ppp')
plt.plot(M_, bL1_mmm, ls='-', label='mmm')

#plt.plot(massbin, (bLs2_mmp+bLs2_ppm)/2., ls='--', label='Eq.(16)')

plt.xscale('log')
#plt.yscale('log')
#plt.xlim(1e12, 1e15)
#plt.ylim(-3, 6)
plt.legend()
#plt.savefig('/home/yinli/csit/analysis/bias/bL1_abmat_003_comp.pdf')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-77dcc0430999> in <module>
# ----> 1 plt.plot(M_, bL1, ls='-', label='Eq.(17) (ppp+mmm)/2')
#       2 plt.plot(M_, bL1_ppp, ls='-', label='ppp')
#       3 plt.plot(M_, bL1_mmm, ls='-', label='mmm')
#       4
#       5 #plt.plot(massbin, (bLs2_mmp+bLs2_ppm)/2., ls='--', label='Eq.(16)')
#
# NameError: name 'bL1' is not defined
